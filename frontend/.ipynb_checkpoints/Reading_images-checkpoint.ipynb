# %% [markdown]
# **Reading images in Python**
# https://www.geeksforgeeks.org/reading-images-in-python/
#
# Python supports very powerful tools when comes to image processing.<br>
# Let’s see how to process the images using different libraries like<br>
# **ImageIO:**
# pip install imageio<br>
# **OpenCV:**
# pip install opencv-python
# pip install numpy
# pip install matplotlib
# **Matplotlib:**
# pip install opencv-python
# pip install numpy
# pip install matplotlib
# **PIL**
# pip install Pillow

# %% [markdown]
# **ImageIO**

# %%
#!pip install imageio
#import imageio as iio
#import imageio.v2 as iio

# %%
path = 'data/clean/0018_size.jpg'

# %%
# read an image
#image = iio.imread(path)

# %%
# write it in a new format
#iio.imwrite(path, image)

# %%
#print(type(image))
#print(image.shape)
#image[:,:,0]

# %% [markdown]
# **Matplotlib**

# %%
import matplotlib.pyplot as plt

# %%
# Read Images
image_plt = plt.imread(path)
print(type(image_plt))
print(image_plt.shape)
plt.imshow(image_plt);
# Out:
# <class 'numpy.ndarray'>
# (341, 256, 3)

# %% [markdown]
# **PIL**

# %%
from PIL import Image

# %%
#img = Image.open('data/clean/009c.jpg')
img = Image.open(path)
print(type(img))
img
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x341 at 0x7F91BF40C670>

# %%
from PIL import Image

# Read image
image_PIL = Image.open(path)
print(type(image_PIL))

# Output Images
#image_PIL.show()

# prints format of image
print(image_PIL.format)

# prints mode of image
print(image_PIL.mode)

# prints size of image: 
print(image_PIL.size)

image_PIL
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# JPEG
# RGB
# (256, 341)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x341 at 0x7F91BF40C640>

# %%
import numpy as np

# PIL => numpy
image_np = np.array(image_PIL) # np.shape: height x width x channel
print(type(image_np))
print(image_np.shape)

# nparray => PIL
image_PIL = Image.fromarray(image_np) # PIL.size: width x height
print(type(image_PIL))
print(image_PIL.size)
# Out:
# <class 'numpy.ndarray'>
# (341, 256, 3)
# <class 'PIL.Image.Image'>
# (256, 341)
